# %%
# Import the dependencies.
import pandas as pd
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
len(coordinates)
# Out:
# 2000

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 747

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        current_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": current_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | saryshagan
# City not found. Skipping...
# Processing Record 2 of Set 1 | mar del plata
# Processing Record 3 of Set 1 | bredasdorp
# Processing Record 4 of Set 1 | longyearbyen
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | chokurdakh
# Processing Record 7 of Set 1 | dubbo
# Processing Record 8 of Set 1 | east london
# Processing Record 9 of Set 1 | goderich
# Processing Record 10 of Set 1 | gao
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | qaanaaq
# Processing Record 13 of Set 1 | victoria
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 16 of Set 1 | barrow
# Processing Record 17 of Set 1 | puerto padre
# Processing Record 18 of Set 1 | beringovskiy
# Processing Record 19 of Set 1 | arraial do cabo
# Processing Record 20 of Set 1 | cherskiy
# Processing Record 21 of Set 1 | paamiut
# Processing Record 22 of Set 1 | teknaf
# Processing Record 23 of Set 1 | talnakh
# Processing Record 24 of Set 1 | mahebourg
# Processing Record 25 of Set 1 | san cristobal
# Processing Record 26 of Set 1 | narsaq
# Processing Record 27 of Set 1 | clyde river
# Processing Record 28 of Set 1 | busselton
# Processing Record 29 of Set 1 | tiksi
# Processing Record 30 of Set 1 | birao
# Processing Record 31 of Set 1 | cape town
# Processing Record 32 of Set 1 | maceio
# Processing Record 33 of Set 1 | katsuura
# Processing Record 34 of Set 1 | burns lake
# Processing Record 35 of Set 1 | bengkulu
# Processing Record 36 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 1 | cabo san lucas
# Processing Record 38 of Set 1 | lebu
# Processing Record 39 of Set 1 | vao
# Processing Record 40 of Set 1 | ivangorod
# Processing Record 41 of Set 1 | hastings
# Processing Record 42 of Set 1 | andros town
# Processing Record 43 of Set 1 | boralday
# Processing Record 44 of Set 1 | neryungri
# Processing Record 45 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 1 | dalby
# Processing Record 47 of Set 1 | oshakati
# Processing Record 48 of Set 1 | college
# Processing Record 49 of Set 1 | faanui
# Processing Record 50 of Set 1 | zachary
# Processing Record 1 of Set 2 | yulara
# Processing Record 2 of Set 2 | hobart
# Processing Record 3 of Set 2 | tombouctou
# Processing Record 4 of Set 2 | pacific grove
# Processing Record 5 of Set 2 | tianpeng
# Processing Record 6 of Set 2 | thompson
# Processing Record 7 of Set 2 | samana
# Processing Record 8 of Set 2 | port shepstone
# Processing Record 9 of Set 2 | humaita
# Processing Record 10 of Set 2 | san patricio
# Processing Record 11 of Set 2 | albany
# Processing Record 12 of Set 2 | ruwi
# Processing Record 13 of Set 2 | gualeguay
# Processing Record 14 of Set 2 | khatanga
# Processing Record 15 of Set 2 | vostok
# Processing Record 16 of Set 2 | vardo
# Processing Record 17 of Set 2 | san clemente
# Processing Record 18 of Set 2 | khandyga
# Processing Record 19 of Set 2 | nichinan
# Processing Record 20 of Set 2 | saldanha
# Processing Record 21 of Set 2 | hilo
# Processing Record 22 of Set 2 | evensk
# Processing Record 23 of Set 2 | punta arenas
# Processing Record 24 of Set 2 | liverpool
# Processing Record 25 of Set 2 | codrington
# Processing Record 26 of Set 2 | atuona
# Processing Record 27 of Set 2 | hofn
# Processing Record 28 of Set 2 | chapais
# Processing Record 29 of Set 2 | san ramon de la nueva oran
# Processing Record 30 of Set 2 | puerto ayora
# Processing Record 31 of Set 2 | progreso
# Processing Record 32 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 2 | vaini
# Processing Record 34 of Set 2 | pevek
# Processing Record 35 of Set 2 | antofagasta
# Processing Record 36 of Set 2 | bluff
# Processing Record 37 of Set 2 | radauti
# Processing Record 38 of Set 2 | kysyl-syr
# Processing Record 39 of Set 2 | ribeira grande
# Processing Record 40 of Set 2 | oktyabrskoye
# Processing Record 41 of Set 2 | santana do acarau
# Processing Record 42 of Set 2 | northam
# Processing Record 43 of Set 2 | shache
# Processing Record 44 of Set 2 | taitung
# Processing Record 45 of Set 2 | kapaa
# Processing Record 46 of Set 2 | lima
# Processing Record 47 of Set 2 | richards bay
# Processing Record 48 of Set 2 | vestmanna
# Processing Record 49 of Set 2 | new norfolk
# Processing Record 50 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 3 | lashio
# Processing Record 2 of Set 3 | diffa
# Processing Record 3 of Set 3 | namatanai
# Processing Record 4 of Set 3 | hasaki
# Processing Record 5 of Set 3 | sahuaripa
# Processing Record 6 of Set 3 | maniitsoq
# Processing Record 7 of Set 3 | olga
# Processing Record 8 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 3 | iquique
# Processing Record 10 of Set 3 | suntar
# Processing Record 11 of Set 3 | nikolskoye
# Processing Record 12 of Set 3 | port alfred
# Processing Record 13 of Set 3 | kaya
# Processing Record 14 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 3 | umm lajj
# Processing Record 16 of Set 3 | huarmey
# Processing Record 17 of Set 3 | tyukhtet
# Processing Record 18 of Set 3 | sajanan
# Processing Record 19 of Set 3 | banamba
# Processing Record 20 of Set 3 | santa maria del oro
# Processing Record 21 of Set 3 | flinders
# Processing Record 22 of Set 3 | carnarvon
# Processing Record 23 of Set 3 | tabou
# Processing Record 24 of Set 3 | haines junction
# Processing Record 25 of Set 3 | hermanus
# Processing Record 26 of Set 3 | butaritari
# Processing Record 27 of Set 3 | san isidro
# Processing Record 28 of Set 3 | san jose
# Processing Record 29 of Set 3 | castro
# Processing Record 30 of Set 3 | mosquera
# Processing Record 31 of Set 3 | shirokiy
# Processing Record 32 of Set 3 | kalmar
# Processing Record 33 of Set 3 | tuatapere
# Processing Record 34 of Set 3 | chumikan
# Processing Record 35 of Set 3 | port lincoln
# Processing Record 36 of Set 3 | havoysund
# Processing Record 37 of Set 3 | saint-philippe
# Processing Record 38 of Set 3 | hokitika
# Processing Record 39 of Set 3 | san matias
# Processing Record 40 of Set 3 | korla
# Processing Record 41 of Set 3 | saskylakh
# Processing Record 42 of Set 3 | kavieng
# Processing Record 43 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 3 | klaksvik
# Processing Record 45 of Set 3 | kaitangata
# Processing Record 46 of Set 3 | phalaborwa
# Processing Record 47 of Set 3 | milingimbi
# City not found. Skipping...
# Processing Record 48 of Set 3 | oudtshoorn
# Processing Record 49 of Set 3 | burnie
# Processing Record 50 of Set 3 | bilibino
# Processing Record 1 of Set 4 | kodiak
# Processing Record 2 of Set 4 | auki
# Processing Record 3 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 4 | tasiilaq
# Processing Record 5 of Set 4 | sorland
# Processing Record 6 of Set 4 | la ronge
# Processing Record 7 of Set 4 | campos do jordao
# Processing Record 8 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 9 of Set 4 | yellowknife
# Processing Record 10 of Set 4 | esperance
# Processing Record 11 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 12 of Set 4 | makinsk
# Processing Record 13 of Set 4 | qinhuangdao
# Processing Record 14 of Set 4 | nemuro
# Processing Record 15 of Set 4 | emerald
# Processing Record 16 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 17 of Set 4 | sabha
# Processing Record 18 of Set 4 | husavik
# Processing Record 19 of Set 4 | komsomolskiy
# Processing Record 20 of Set 4 | vila franca do campo
# Processing Record 21 of Set 4 | fortuna
# Processing Record 22 of Set 4 | rovaniemi
# Processing Record 23 of Set 4 | avarua
# Processing Record 24 of Set 4 | jamestown
# Processing Record 25 of Set 4 | shaunavon
# Processing Record 26 of Set 4 | angatuba
# Processing Record 27 of Set 4 | bethel
# Processing Record 28 of Set 4 | dikson
# Processing Record 29 of Set 4 | hazaribag
# Processing Record 30 of Set 4 | nanga eboko
# Processing Record 31 of Set 4 | pacasmayo
# Processing Record 32 of Set 4 | bowen
# Processing Record 33 of Set 4 | araouane
# Processing Record 34 of Set 4 | cheuskiny
# City not found. Skipping...
# Processing Record 35 of Set 4 | ferkessedougou
# Processing Record 36 of Set 4 | turbana
# Processing Record 37 of Set 4 | giyani
# Processing Record 38 of Set 4 | manokwari
# Processing Record 39 of Set 4 | norman wells
# Processing Record 40 of Set 4 | normandin
# Processing Record 41 of Set 4 | upernavik
# Processing Record 42 of Set 4 | turkistan
# Processing Record 43 of Set 4 | hithadhoo
# Processing Record 44 of Set 4 | bokspits
# City not found. Skipping...
# Processing Record 45 of Set 4 | morondava
# Processing Record 46 of Set 4 | saint-augustin
# Processing Record 47 of Set 4 | yerbogachen
# Processing Record 48 of Set 4 | garowe
# Processing Record 49 of Set 4 | port augusta
# Processing Record 50 of Set 4 | khash
# Processing Record 1 of Set 5 | chuy
# Processing Record 2 of Set 5 | karratha
# Processing Record 3 of Set 5 | severo-kurilsk
# Processing Record 4 of Set 5 | aasiaat
# Processing Record 5 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 5 | bongandanga
# Processing Record 7 of Set 5 | arlit
# Processing Record 8 of Set 5 | kaeo
# Processing Record 9 of Set 5 | chara
# Processing Record 10 of Set 5 | nangong
# Processing Record 11 of Set 5 | baturaja
# Processing Record 12 of Set 5 | axim
# Processing Record 13 of Set 5 | oistins
# Processing Record 14 of Set 5 | luau
# Processing Record 15 of Set 5 | leningradskiy
# Processing Record 16 of Set 5 | naze
# Processing Record 17 of Set 5 | kruisfontein
# Processing Record 18 of Set 5 | wanning
# Processing Record 19 of Set 5 | vila
# Processing Record 20 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 5 | marsh harbour
# Processing Record 22 of Set 5 | pisco
# Processing Record 23 of Set 5 | tahta
# Processing Record 24 of Set 5 | darnah
# Processing Record 25 of Set 5 | salalah
# Processing Record 26 of Set 5 | saint-francois
# Processing Record 27 of Set 5 | bubaque
# Processing Record 28 of Set 5 | manicore
# Processing Record 29 of Set 5 | ixtapa
# Processing Record 30 of Set 5 | palera
# Processing Record 31 of Set 5 | atambua
# Processing Record 32 of Set 5 | deer lake
# Processing Record 33 of Set 5 | fort abbas
# Processing Record 34 of Set 5 | tessalit
# Processing Record 35 of Set 5 | kavaratti
# Processing Record 36 of Set 5 | port elizabeth
# Processing Record 37 of Set 5 | evansville
# Processing Record 38 of Set 5 | glendive
# Processing Record 39 of Set 5 | zaraza
# Processing Record 40 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 5 | kyren
# Processing Record 42 of Set 5 | taltal
# Processing Record 43 of Set 5 | arman
# Processing Record 44 of Set 5 | shimoda
# Processing Record 45 of Set 5 | lagoa
# Processing Record 46 of Set 5 | takayama
# Processing Record 47 of Set 5 | vestmannaeyjar
# Processing Record 48 of Set 5 | salisbury
# Processing Record 49 of Set 5 | tuktoyaktuk
# Processing Record 50 of Set 5 | hovd
# Processing Record 1 of Set 6 | amapa
# Processing Record 2 of Set 6 | sao borja
# Processing Record 3 of Set 6 | la asuncion
# Processing Record 4 of Set 6 | avera
# Processing Record 5 of Set 6 | walvis bay
# Processing Record 6 of Set 6 | nanortalik
# Processing Record 7 of Set 6 | buala
# Processing Record 8 of Set 6 | mizdah
# Processing Record 9 of Set 6 | mount gambier
# Processing Record 10 of Set 6 | quelimane
# Processing Record 11 of Set 6 | villa carlos paz
# Processing Record 12 of Set 6 | oskemen
# Processing Record 13 of Set 6 | sakakah
# Processing Record 14 of Set 6 | road town
# Processing Record 15 of Set 6 | areosa
# Processing Record 16 of Set 6 | lorengau
# Processing Record 17 of Set 6 | anadyr
# Processing Record 18 of Set 6 | samarai
# Processing Record 19 of Set 6 | dobronin
# Processing Record 20 of Set 6 | bata
# Processing Record 21 of Set 6 | makakilo city
# Processing Record 22 of Set 6 | cidreira
# Processing Record 23 of Set 6 | lompoc
# Processing Record 24 of Set 6 | edd
# Processing Record 25 of Set 6 | ilulissat
# Processing Record 26 of Set 6 | gilgit
# Processing Record 27 of Set 6 | palanga
# Processing Record 28 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 6 | lahat
# Processing Record 30 of Set 6 | black river
# Processing Record 31 of Set 6 | mutoko
# Processing Record 32 of Set 6 | kimbe
# Processing Record 33 of Set 6 | buchanan
# Processing Record 34 of Set 6 | kula
# Processing Record 35 of Set 6 | portland
# Processing Record 36 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 6 | xining
# Processing Record 38 of Set 6 | sao filipe
# Processing Record 39 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 40 of Set 6 | petrozavodsk
# Processing Record 41 of Set 6 | fianga
# City not found. Skipping...
# Processing Record 42 of Set 6 | westport
# Processing Record 43 of Set 6 | shurugwi
# Processing Record 44 of Set 6 | corinto
# Processing Record 45 of Set 6 | mahanje
# Processing Record 46 of Set 6 | le port
# Processing Record 47 of Set 6 | sao jose da coroa grande
# Processing Record 48 of Set 6 | conway
# Processing Record 49 of Set 6 | el alto
# Processing Record 50 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 1 of Set 7 | cassilandia
# Processing Record 2 of Set 7 | chanute
# Processing Record 3 of Set 7 | kulhudhuffushi
# Processing Record 4 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 5 of Set 7 | quatre cocos
# Processing Record 6 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 7 of Set 7 | lahij
# Processing Record 8 of Set 7 | torbay
# Processing Record 9 of Set 7 | kidal
# Processing Record 10 of Set 7 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 11 of Set 7 | byron bay
# Processing Record 12 of Set 7 | port hardy
# Processing Record 13 of Set 7 | soto la marina
# Processing Record 14 of Set 7 | half moon bay
# Processing Record 15 of Set 7 | matto
# City not found. Skipping...
# Processing Record 16 of Set 7 | souillac
# Processing Record 17 of Set 7 | ekuvukeni
# Processing Record 18 of Set 7 | plastun
# Processing Record 19 of Set 7 | jvari
# Processing Record 20 of Set 7 | auburn
# Processing Record 21 of Set 7 | malakal
# Processing Record 22 of Set 7 | chaa-khol
# City not found. Skipping...
# Processing Record 23 of Set 7 | lata
# Processing Record 24 of Set 7 | san giorgio ionico
# Processing Record 25 of Set 7 | altay
# Processing Record 26 of Set 7 | bodden town
# Processing Record 27 of Set 7 | necochea
# Processing Record 28 of Set 7 | airai
# Processing Record 29 of Set 7 | baykit
# Processing Record 30 of Set 7 | naftah
# City not found. Skipping...
# Processing Record 31 of Set 7 | ewa beach
# Processing Record 32 of Set 7 | caravelas
# Processing Record 33 of Set 7 | mnogovershinnyy
# Processing Record 34 of Set 7 | pangody
# Processing Record 35 of Set 7 | oranjemund
# Processing Record 36 of Set 7 | constitucion
# Processing Record 37 of Set 7 | namibe
# Processing Record 38 of Set 7 | fougamou
# Processing Record 39 of Set 7 | isla mujeres
# Processing Record 40 of Set 7 | trelew
# Processing Record 41 of Set 7 | calama
# Processing Record 42 of Set 7 | aklavik
# Processing Record 43 of Set 7 | bairiki
# Processing Record 44 of Set 7 | wyndham
# Processing Record 45 of Set 7 | nakambala
# Processing Record 46 of Set 7 | roald
# Processing Record 47 of Set 7 | boca do acre
# Processing Record 48 of Set 7 | namwala
# Processing Record 49 of Set 7 | saquena
# Processing Record 50 of Set 7 | sobolevo
# Processing Record 1 of Set 8 | tolaga bay
# Processing Record 2 of Set 8 | camacha
# Processing Record 3 of Set 8 | miles city
# Processing Record 4 of Set 8 | san policarpo
# Processing Record 5 of Set 8 | aktas
# Processing Record 6 of Set 8 | krotovka
# Processing Record 7 of Set 8 | laguna
# Processing Record 8 of Set 8 | tura
# Processing Record 9 of Set 8 | saint anthony
# Processing Record 10 of Set 8 | boa vista
# Processing Record 11 of Set 8 | bonthe
# Processing Record 12 of Set 8 | macklin
# Processing Record 13 of Set 8 | luby
# Processing Record 14 of Set 8 | rocha
# Processing Record 15 of Set 8 | derzhavinsk
# Processing Record 16 of Set 8 | baft
# Processing Record 17 of Set 8 | chipata
# Processing Record 18 of Set 8 | aksarka
# Processing Record 19 of Set 8 | isangel
# Processing Record 20 of Set 8 | kondinskoye
# Processing Record 21 of Set 8 | batemans bay
# Processing Record 22 of Set 8 | panaba
# Processing Record 23 of Set 8 | ponta do sol
# Processing Record 24 of Set 8 | tabialan
# City not found. Skipping...
# Processing Record 25 of Set 8 | chiungutwa
# Processing Record 26 of Set 8 | druzhba
# Processing Record 27 of Set 8 | ende
# Processing Record 28 of Set 8 | miquelon
# Processing Record 29 of Set 8 | sabang
# Processing Record 30 of Set 8 | muros
# Processing Record 31 of Set 8 | alta floresta
# Processing Record 32 of Set 8 | briancon
# Processing Record 33 of Set 8 | juegang
# Processing Record 34 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 35 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 8 | srednekolymsk
# Processing Record 37 of Set 8 | humberto de campos
# Processing Record 38 of Set 8 | ondorhaan
# City not found. Skipping...
# Processing Record 39 of Set 8 | maniwaki
# Processing Record 40 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 8 | riviere-du-loup
# Processing Record 42 of Set 8 | najran
# Processing Record 43 of Set 8 | miraflores
# Processing Record 44 of Set 8 | anjozorobe
# Processing Record 45 of Set 8 | birobidzhan
# Processing Record 46 of Set 8 | adrar
# Processing Record 47 of Set 8 | padang
# Processing Record 48 of Set 8 | la palma
# Processing Record 49 of Set 8 | russell
# Processing Record 50 of Set 8 | fenoarivo
# Processing Record 1 of Set 9 | ust-kuyga
# Processing Record 2 of Set 9 | touros
# Processing Record 3 of Set 9 | champerico
# Processing Record 4 of Set 9 | mayumba
# Processing Record 5 of Set 9 | saryg-sep
# Processing Record 6 of Set 9 | guymon
# Processing Record 7 of Set 9 | praia da vitoria
# Processing Record 8 of Set 9 | berbera
# Processing Record 9 of Set 9 | georgetown
# Processing Record 10 of Set 9 | blackfoot
# Processing Record 11 of Set 9 | sola
# Processing Record 12 of Set 9 | alyangula
# Processing Record 13 of Set 9 | hami
# Processing Record 14 of Set 9 | sioux lookout
# Processing Record 15 of Set 9 | bujak
# Processing Record 16 of Set 9 | lake charles
# Processing Record 17 of Set 9 | shaturtorf
# Processing Record 18 of Set 9 | lokosovo
# Processing Record 19 of Set 9 | provideniya
# Processing Record 20 of Set 9 | shenjiamen
# Processing Record 21 of Set 9 | basco
# Processing Record 22 of Set 9 | roches noires
# City not found. Skipping...
# Processing Record 23 of Set 9 | lazurne
# Processing Record 24 of Set 9 | mecca
# Processing Record 25 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 9 | angren
# Processing Record 27 of Set 9 | okhotsk
# Processing Record 28 of Set 9 | kununurra
# Processing Record 29 of Set 9 | sinkat
# City not found. Skipping...
# Processing Record 30 of Set 9 | esso
# Processing Record 31 of Set 9 | odzaci
# Processing Record 32 of Set 9 | itarema
# Processing Record 33 of Set 9 | jawhar
# Processing Record 34 of Set 9 | gravdal
# Processing Record 35 of Set 9 | mandalgovi
# Processing Record 36 of Set 9 | coquimbo
# Processing Record 37 of Set 9 | labuhan
# Processing Record 38 of Set 9 | inirida
# Processing Record 39 of Set 9 | novikovo
# Processing Record 40 of Set 9 | okha
# Processing Record 41 of Set 9 | caohai
# Processing Record 42 of Set 9 | cotorra
# Processing Record 43 of Set 9 | lavrentiya
# Processing Record 44 of Set 9 | guarapari
# Processing Record 45 of Set 9 | gat
# Processing Record 46 of Set 9 | beidao
# Processing Record 47 of Set 9 | olot
# Processing Record 48 of Set 9 | cockburn town
# Processing Record 49 of Set 9 | trairi
# Processing Record 50 of Set 9 | ararat
# Processing Record 1 of Set 10 | bambous virieux
# Processing Record 2 of Set 10 | baruun-urt
# Processing Record 3 of Set 10 | coihaique
# Processing Record 4 of Set 10 | sumbawanga
# Processing Record 5 of Set 10 | kyaikto
# Processing Record 6 of Set 10 | nyurba
# Processing Record 7 of Set 10 | faya
# Processing Record 8 of Set 10 | semey
# Processing Record 9 of Set 10 | mongo
# Processing Record 10 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 11 of Set 10 | claresholm
# Processing Record 12 of Set 10 | stavern
# Processing Record 13 of Set 10 | kiunga
# Processing Record 14 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 15 of Set 10 | sand springs
# Processing Record 16 of Set 10 | maldonado
# Processing Record 17 of Set 10 | luderitz
# Processing Record 18 of Set 10 | eidsvag
# Processing Record 19 of Set 10 | flin flon
# Processing Record 20 of Set 10 | dzerzhinsk
# Processing Record 21 of Set 10 | darhan
# Processing Record 22 of Set 10 | mutsamudu
# City not found. Skipping...
# Processing Record 23 of Set 10 | jiazi
# Processing Record 24 of Set 10 | tuskegee
# Processing Record 25 of Set 10 | brae
# Processing Record 26 of Set 10 | sitka
# Processing Record 27 of Set 10 | dombas
# Processing Record 28 of Set 10 | whitchurch-stouffville
# City not found. Skipping...
# Processing Record 29 of Set 10 | balabac
# Processing Record 30 of Set 10 | bathsheba
# Processing Record 31 of Set 10 | mporokoso
# Processing Record 32 of Set 10 | vondrozo
# Processing Record 33 of Set 10 | lokomotivnyy
# Processing Record 34 of Set 10 | murdochville
# Processing Record 35 of Set 10 | ozernovskiy
# Processing Record 36 of Set 10 | roma
# Processing Record 37 of Set 10 | blythe
# Processing Record 38 of Set 10 | astoria
# Processing Record 39 of Set 10 | ostrovnoy
# Processing Record 40 of Set 10 | lexington park
# Processing Record 41 of Set 10 | damietta
# Processing Record 42 of Set 10 | candelaria
# Processing Record 43 of Set 10 | yenagoa
# Processing Record 44 of Set 10 | waipawa
# Processing Record 45 of Set 10 | bang saphan
# Processing Record 46 of Set 10 | taseyevo
# Processing Record 47 of Set 10 | hede
# Processing Record 48 of Set 10 | lamu
# Processing Record 49 of Set 10 | goma
# Processing Record 50 of Set 10 | lewiston
# Processing Record 1 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 2 of Set 11 | geraldton
# Processing Record 3 of Set 11 | podgorica
# Processing Record 4 of Set 11 | bombay
# Processing Record 5 of Set 11 | oxbow
# Processing Record 6 of Set 11 | lisakovsk
# Processing Record 7 of Set 11 | carutapera
# Processing Record 8 of Set 11 | atar
# Processing Record 9 of Set 11 | shushary
# Processing Record 10 of Set 11 | shubarkuduk
# Processing Record 11 of Set 11 | namtsy
# Processing Record 12 of Set 11 | luoyang
# Processing Record 13 of Set 11 | beroroha
# Processing Record 14 of Set 11 | baracoa
# Processing Record 15 of Set 11 | krasnoselkup
# Processing Record 16 of Set 11 | akureyri
# Processing Record 17 of Set 11 | gorontalo
# Processing Record 18 of Set 11 | mountain home
# Processing Record 19 of Set 11 | grindavik
# Processing Record 20 of Set 11 | tiznit
# Processing Record 21 of Set 11 | yangjiang
# Processing Record 22 of Set 11 | kloulklubed
# Processing Record 23 of Set 11 | belmonte
# Processing Record 24 of Set 11 | kirakira
# Processing Record 25 of Set 11 | voh
# Processing Record 26 of Set 11 | homer
# Processing Record 27 of Set 11 | takaungu
# Processing Record 28 of Set 11 | barcelona
# Processing Record 29 of Set 11 | henties bay
# Processing Record 30 of Set 11 | agadez
# Processing Record 31 of Set 11 | valparaiso
# Processing Record 32 of Set 11 | romanovka
# Processing Record 33 of Set 11 | nagapattinam
# Processing Record 34 of Set 11 | vanimo
# Processing Record 35 of Set 11 | shebalino
# Processing Record 36 of Set 11 | kermanshah
# Processing Record 37 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 38 of Set 11 | elizabeth city
# Processing Record 39 of Set 11 | bida
# Processing Record 40 of Set 11 | alekseyevsk
# Processing Record 41 of Set 11 | sambava
# Processing Record 42 of Set 11 | fort saint james
# Processing Record 43 of Set 11 | saint george
# Processing Record 44 of Set 11 | hambantota
# Processing Record 45 of Set 11 | merauke
# Processing Record 46 of Set 11 | linhares
# Processing Record 47 of Set 11 | kijang
# Processing Record 48 of Set 11 | tezu
# Processing Record 49 of Set 11 | deep river
# Processing Record 50 of Set 11 | berlevag
# Processing Record 1 of Set 12 | prince george
# Processing Record 2 of Set 12 | eskasem
# City not found. Skipping...
# Processing Record 3 of Set 12 | sol-iletsk
# Processing Record 4 of Set 12 | carauari
# Processing Record 5 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 6 of Set 12 | prabumulih
# Processing Record 7 of Set 12 | rehoboth
# Processing Record 8 of Set 12 | porangatu
# Processing Record 9 of Set 12 | qaqortoq
# Processing Record 10 of Set 12 | ciras
# City not found. Skipping...
# Processing Record 11 of Set 12 | scottsburgh
# City not found. Skipping...
# Processing Record 12 of Set 12 | iquitos
# Processing Record 13 of Set 12 | ust-maya
# Processing Record 14 of Set 12 | ahumada
# City not found. Skipping...
# Processing Record 15 of Set 12 | alamogordo
# Processing Record 16 of Set 12 | korem
# Processing Record 17 of Set 12 | sept-iles
# Processing Record 18 of Set 12 | sao fidelis
# Processing Record 19 of Set 12 | wamba
# Processing Record 20 of Set 12 | belaya gora
# Processing Record 21 of Set 12 | buluang
# Processing Record 22 of Set 12 | mergui
# City not found. Skipping...
# Processing Record 23 of Set 12 | biu
# Processing Record 24 of Set 12 | ilhabela
# Processing Record 25 of Set 12 | dzhebariki-khaya
# Processing Record 26 of Set 12 | aswan
# Processing Record 27 of Set 12 | sovetskiy
# Processing Record 28 of Set 12 | zapolyarnyy
# Processing Record 29 of Set 12 | porto santo
# Processing Record 30 of Set 12 | puerto quijarro
# Processing Record 31 of Set 12 | kayerkan
# Processing Record 32 of Set 12 | ojitlan
# City not found. Skipping...
# Processing Record 33 of Set 12 | madang
# Processing Record 34 of Set 12 | maningrida
# Processing Record 35 of Set 12 | myitkyina
# Processing Record 36 of Set 12 | sao felix do xingu
# Processing Record 37 of Set 12 | bati
# Processing Record 38 of Set 12 | freeport
# Processing Record 39 of Set 12 | teya
# Processing Record 40 of Set 12 | fairbanks
# Processing Record 41 of Set 12 | nacala
# Processing Record 42 of Set 12 | iwanai
# Processing Record 43 of Set 12 | bilma
# Processing Record 44 of Set 12 | egvekinot
# Processing Record 45 of Set 12 | sangmelima
# Processing Record 46 of Set 12 | sao joao da barra
# Processing Record 47 of Set 12 | kahului
# Processing Record 48 of Set 12 | burica
# City not found. Skipping...
# Processing Record 49 of Set 12 | high level
# Processing Record 50 of Set 12 | sal rei
# Processing Record 1 of Set 13 | bull savanna
# Processing Record 2 of Set 13 | ximei
# Processing Record 3 of Set 13 | polunochnoye
# Processing Record 4 of Set 13 | talcahuano
# Processing Record 5 of Set 13 | campana
# Processing Record 6 of Set 13 | tigzirt
# Processing Record 7 of Set 13 | komadi
# Processing Record 8 of Set 13 | viedma
# Processing Record 9 of Set 13 | voyinka
# Processing Record 10 of Set 13 | tezpur
# Processing Record 11 of Set 13 | port-gentil
# Processing Record 12 of Set 13 | inhambane
# Processing Record 13 of Set 13 | isiro
# Processing Record 14 of Set 13 | imbituba
# Processing Record 15 of Set 13 | takoradi
# Processing Record 16 of Set 13 | balkhash
# Processing Record 17 of Set 13 | sangareddi
# Processing Record 18 of Set 13 | ketchikan
# Processing Record 19 of Set 13 | shushtar
# Processing Record 20 of Set 13 | weihe
# Processing Record 21 of Set 13 | buraydah
# Processing Record 22 of Set 13 | balimo
# City not found. Skipping...
# Processing Record 23 of Set 13 | luxeuil-les-bains
# Processing Record 24 of Set 13 | lazaro cardenas
# Processing Record 25 of Set 13 | camargo
# Processing Record 26 of Set 13 | honiara
# Processing Record 27 of Set 13 | nsanje
# Processing Record 28 of Set 13 | marshfield
# Processing Record 29 of Set 13 | morgan city
# Processing Record 30 of Set 13 | puerto narino
# Processing Record 31 of Set 13 | davila
# Processing Record 32 of Set 13 | hermosillo
# Processing Record 33 of Set 13 | termoli
# Processing Record 34 of Set 13 | valley station
# Processing Record 35 of Set 13 | mehamn
# Processing Record 36 of Set 13 | port blair
# Processing Record 37 of Set 13 | biak
# Processing Record 38 of Set 13 | el cobre
# Processing Record 39 of Set 13 | honggang
# Processing Record 40 of Set 13 | tarko-sale
# Processing Record 41 of Set 13 | dujuma
# City not found. Skipping...
# Processing Record 42 of Set 13 | kattivakkam
# Processing Record 43 of Set 13 | moose factory
# Processing Record 44 of Set 13 | nizwa
# Processing Record 45 of Set 13 | marquette
# Processing Record 46 of Set 13 | sao raimundo nonato
# Processing Record 47 of Set 13 | san luis
# Processing Record 48 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 49 of Set 13 | marzuq
# Processing Record 50 of Set 13 | zhigansk
# Processing Record 1 of Set 14 | huanta
# Processing Record 2 of Set 14 | stillwater
# Processing Record 3 of Set 14 | kakinada
# Processing Record 4 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 5 of Set 14 | mahibadhoo
# Processing Record 6 of Set 14 | whitianga
# Processing Record 7 of Set 14 | phan rang
# City not found. Skipping...
# Processing Record 8 of Set 14 | ovsyanka
# Processing Record 9 of Set 14 | poso
# Processing Record 10 of Set 14 | ancud
# Processing Record 11 of Set 14 | pangnirtung
# Processing Record 12 of Set 14 | opatija
# Processing Record 13 of Set 14 | bouloupari
# Processing Record 14 of Set 14 | sangar
# Processing Record 15 of Set 14 | kuminskiy
# Processing Record 16 of Set 14 | hegang
# Processing Record 17 of Set 14 | kawana waters
# City not found. Skipping...
# Processing Record 18 of Set 14 | malanje
# Processing Record 19 of Set 14 | schwabisch gmund
# Processing Record 20 of Set 14 | kilindoni
# Processing Record 21 of Set 14 | lixourion
# Processing Record 22 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 23 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 14 | matamoros
# Processing Record 25 of Set 14 | mount isa
# Processing Record 26 of Set 14 | bara
# Processing Record 27 of Set 14 | isabela
# Processing Record 28 of Set 14 | zastron
# Processing Record 29 of Set 14 | betsiamites
# Processing Record 30 of Set 14 | karnobat
# Processing Record 31 of Set 14 | noumea
# Processing Record 32 of Set 14 | asfi
# Processing Record 33 of Set 14 | tawkar
# City not found. Skipping...
# Processing Record 34 of Set 14 | pilos
# City not found. Skipping...
# Processing Record 35 of Set 14 | george
# Processing Record 36 of Set 14 | zaysan
# Processing Record 37 of Set 14 | sao bernardo
# Processing Record 38 of Set 14 | muzhi
# Processing Record 39 of Set 14 | eydhafushi
# Processing Record 40 of Set 14 | natal
# Processing Record 41 of Set 14 | kenai
# Processing Record 42 of Set 14 | east millcreek
# Processing Record 43 of Set 14 | usinsk
# Processing Record 44 of Set 14 | guane
# Processing Record 45 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 46 of Set 14 | tumsar
# Processing Record 47 of Set 14 | palmas bellas
# Processing Record 48 of Set 14 | sarangani
# Processing Record 49 of Set 14 | benjamin hill
# Processing Record 50 of Set 14 | ploemeur
# Processing Record 1 of Set 15 | nome
# Processing Record 2 of Set 15 | bandarbeyla
# Processing Record 3 of Set 15 | cayenne
# Processing Record 4 of Set 15 | perevolotskiy
# Processing Record 5 of Set 15 | bambanglipuro
# Processing Record 6 of Set 15 | damara
# Processing Record 7 of Set 15 | brandon
# Processing Record 8 of Set 15 | felanitx
# Processing Record 9 of Set 15 | ilorin
# Processing Record 10 of Set 15 | mokhsogollokh
# Processing Record 11 of Set 15 | makung
# City not found. Skipping...
# Processing Record 12 of Set 15 | omsukchan
# Processing Record 13 of Set 15 | batouri
# Processing Record 14 of Set 15 | toronto
# Processing Record 15 of Set 15 | bam
# Processing Record 16 of Set 15 | sento se
# City not found. Skipping...
# Processing Record 17 of Set 15 | taoudenni
# Processing Record 18 of Set 15 | mayo
# Processing Record 19 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 15 | riyadh
# Processing Record 21 of Set 15 | nova olimpia
# Processing Record 22 of Set 15 | ukiah
# Processing Record 23 of Set 15 | santa rosa
# Processing Record 24 of Set 15 | houma
# Processing Record 25 of Set 15 | christiana
# Processing Record 26 of Set 15 | glenwood springs
# Processing Record 27 of Set 15 | nurota
# Processing Record 28 of Set 15 | itoman
# Processing Record 29 of Set 15 | venice
# Processing Record 30 of Set 15 | waingapu
# Processing Record 31 of Set 15 | mogok
# Processing Record 32 of Set 15 | tsuruga
# Processing Record 33 of Set 15 | baiyin
# Processing Record 34 of Set 15 | temple
# Processing Record 35 of Set 15 | balakovo
# Processing Record 36 of Set 15 | pafos
# Processing Record 37 of Set 15 | alta
# Processing Record 38 of Set 15 | bonavista
# Processing Record 39 of Set 15 | pacocha
# Processing Record 40 of Set 15 | coos bay
# Processing Record 41 of Set 15 | rantauprapat
# Processing Record 42 of Set 15 | bad doberan
# Processing Record 43 of Set 15 | tigil
# Processing Record 44 of Set 15 | silver city
# Processing Record 45 of Set 15 | yumen
# Processing Record 46 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 47 of Set 15 | phibun mangsahan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
weather_database_df=pd.DataFrame(city_data)
weather_database_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Mar Del Plata      AR -38.0023  -57.5575     64.87        91         100
# 1     Bredasdorp      ZA -34.5322   20.0403     79.56        37          25
# 2   Longyearbyen      SJ  78.2186   15.6401     19.24        63          40
# 3        Ushuaia      AR -54.8000  -68.3000     55.06        58          75
# 4     Chokurdakh      RU  70.6333  147.9167    -39.28       100          99
# 5          Dubbo      AU -32.2500  148.6167     55.53        94          34
# 6    East London      ZA -33.0153   27.9116     75.67        80           4
# 7       Goderich      CA  43.7501  -81.7165     26.91        80          99
# 8            Gao      ML  16.6362    1.6370     81.37         8           0
# 9        Rikitea      PF -23.1203 -134.9692     78.78        71          91
#
#    Wind Speed Current Description
# 0       23.00     overcast clouds
# 1        9.86    scattered clouds
# 2       19.57    scattered clouds
# 3        5.75       broken clouds
# 4        2.21     overcast clouds
# 5        8.05    scattered clouds
# 6       23.53           clear sky
# 7       19.98     overcast clouds
# 8       10.16           clear sky
# 9       16.08     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/Weather_database.csv"
# Export the City_Data into a CSV.
weather_database_df.to_csv(output_data_file, index_label="City_ID")
