# %%
# Import the dependencies.
import pandas as pd
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
len(coordinates)
# Out:
# 2000

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 752

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        current_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": current_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | mende
# Processing Record 2 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 4 of Set 1 | inhambane
# Processing Record 5 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 1 | tiksi
# Processing Record 7 of Set 1 | port alfred
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | bluff
# Processing Record 10 of Set 1 | floro
# Processing Record 11 of Set 1 | jamestown
# Processing Record 12 of Set 1 | butaritari
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | leh
# Processing Record 16 of Set 1 | saskylakh
# Processing Record 17 of Set 1 | tuatapere
# Processing Record 18 of Set 1 | mar del plata
# Processing Record 19 of Set 1 | ribeira grande
# Processing Record 20 of Set 1 | chimbote
# Processing Record 21 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 1 | pipar
# Processing Record 23 of Set 1 | new norfolk
# Processing Record 24 of Set 1 | caravelas
# Processing Record 25 of Set 1 | tuktoyaktuk
# Processing Record 26 of Set 1 | cape town
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | el salto
# Processing Record 29 of Set 1 | lebu
# Processing Record 30 of Set 1 | kurilsk
# Processing Record 31 of Set 1 | kavaratti
# Processing Record 32 of Set 1 | pasni
# Processing Record 33 of Set 1 | general pico
# Processing Record 34 of Set 1 | barra dos coqueiros
# Processing Record 35 of Set 1 | lannion
# Processing Record 36 of Set 1 | avarua
# Processing Record 37 of Set 1 | punta arenas
# Processing Record 38 of Set 1 | saint-joseph
# Processing Record 39 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 40 of Set 1 | hobart
# Processing Record 41 of Set 1 | krasnoselkup
# Processing Record 42 of Set 1 | mirnyy
# Processing Record 43 of Set 1 | pangnirtung
# Processing Record 44 of Set 1 | tura
# Processing Record 45 of Set 1 | nome
# Processing Record 46 of Set 1 | hilo
# Processing Record 47 of Set 1 | jining
# Processing Record 48 of Set 1 | hermanus
# Processing Record 49 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 1 | santa fe
# Processing Record 1 of Set 2 | souillac
# Processing Record 2 of Set 2 | dolgoye
# Processing Record 3 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 5 of Set 2 | okandja
# City not found. Skipping...
# Processing Record 6 of Set 2 | pipri
# Processing Record 7 of Set 2 | atuona
# Processing Record 8 of Set 2 | rio grande
# Processing Record 9 of Set 2 | aranos
# Processing Record 10 of Set 2 | barkhan
# Processing Record 11 of Set 2 | korla
# Processing Record 12 of Set 2 | touros
# Processing Record 13 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 14 of Set 2 | nanortalik
# Processing Record 15 of Set 2 | the valley
# Processing Record 16 of Set 2 | hofn
# Processing Record 17 of Set 2 | cleveland
# Processing Record 18 of Set 2 | okhotsk
# Processing Record 19 of Set 2 | vila velha
# Processing Record 20 of Set 2 | isabela
# Processing Record 21 of Set 2 | diffa
# Processing Record 22 of Set 2 | cidreira
# Processing Record 23 of Set 2 | vila franca do campo
# Processing Record 24 of Set 2 | kodiak
# Processing Record 25 of Set 2 | whyalla
# Processing Record 26 of Set 2 | airai
# Processing Record 27 of Set 2 | albany
# Processing Record 28 of Set 2 | mvuma
# Processing Record 29 of Set 2 | bulgan
# Processing Record 30 of Set 2 | longyearbyen
# Processing Record 31 of Set 2 | rochester
# Processing Record 32 of Set 2 | port-gentil
# Processing Record 33 of Set 2 | sola
# Processing Record 34 of Set 2 | katsuura
# Processing Record 35 of Set 2 | kamenka
# Processing Record 36 of Set 2 | ngunguru
# Processing Record 37 of Set 2 | pecos
# Processing Record 38 of Set 2 | dikson
# Processing Record 39 of Set 2 | vaini
# Processing Record 40 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 2 | tecoanapa
# Processing Record 42 of Set 2 | darfo
# Processing Record 43 of Set 2 | meulaboh
# Processing Record 44 of Set 2 | saint-philippe
# Processing Record 45 of Set 2 | kysyl-syr
# Processing Record 46 of Set 2 | barabai
# Processing Record 47 of Set 2 | nouadhibou
# Processing Record 48 of Set 2 | qaanaaq
# Processing Record 49 of Set 2 | florencia
# Processing Record 50 of Set 2 | yulara
# Processing Record 1 of Set 3 | labuhan
# Processing Record 2 of Set 3 | agadez
# Processing Record 3 of Set 3 | severo-kurilsk
# Processing Record 4 of Set 3 | barrow
# Processing Record 5 of Set 3 | sur
# Processing Record 6 of Set 3 | lermontovka
# Processing Record 7 of Set 3 | sivas
# Processing Record 8 of Set 3 | beidao
# Processing Record 9 of Set 3 | samarai
# Processing Record 10 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 3 | hovd
# Processing Record 12 of Set 3 | lompoc
# Processing Record 13 of Set 3 | koufalia
# Processing Record 14 of Set 3 | skiros
# City not found. Skipping...
# Processing Record 15 of Set 3 | bambous virieux
# Processing Record 16 of Set 3 | east london
# Processing Record 17 of Set 3 | galesong
# Processing Record 18 of Set 3 | viedma
# Processing Record 19 of Set 3 | constitucion
# Processing Record 20 of Set 3 | clyde river
# Processing Record 21 of Set 3 | salamanca
# Processing Record 22 of Set 3 | pevek
# Processing Record 23 of Set 3 | galle
# Processing Record 24 of Set 3 | khatanga
# Processing Record 25 of Set 3 | bethel
# Processing Record 26 of Set 3 | saint george
# Processing Record 27 of Set 3 | lloydminster
# Processing Record 28 of Set 3 | baykit
# Processing Record 29 of Set 3 | tuy hoa
# Processing Record 30 of Set 3 | ilhabela
# Processing Record 31 of Set 3 | drayton valley
# Processing Record 32 of Set 3 | pacific grove
# Processing Record 33 of Set 3 | mahebourg
# Processing Record 34 of Set 3 | barbar
# City not found. Skipping...
# Processing Record 35 of Set 3 | carnarvon
# Processing Record 36 of Set 3 | ormara
# Processing Record 37 of Set 3 | bitung
# Processing Record 38 of Set 3 | honiton
# Processing Record 39 of Set 3 | taoudenni
# Processing Record 40 of Set 3 | puerto ayora
# Processing Record 41 of Set 3 | juneau
# Processing Record 42 of Set 3 | ibotirama
# Processing Record 43 of Set 3 | ostrovnoy
# Processing Record 44 of Set 3 | talnakh
# Processing Record 45 of Set 3 | aitape
# Processing Record 46 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 3 | balaka
# Processing Record 48 of Set 3 | thompson
# Processing Record 49 of Set 3 | kapaa
# Processing Record 50 of Set 3 | seymchan
# Processing Record 1 of Set 4 | wanaka
# Processing Record 2 of Set 4 | jardim
# Processing Record 3 of Set 4 | hambantota
# Processing Record 4 of Set 4 | kiama
# Processing Record 5 of Set 4 | hasaki
# Processing Record 6 of Set 4 | akcaabat
# Processing Record 7 of Set 4 | alexandria
# Processing Record 8 of Set 4 | castro
# Processing Record 9 of Set 4 | sao filipe
# Processing Record 10 of Set 4 | bathsheba
# Processing Record 11 of Set 4 | huamachuco
# Processing Record 12 of Set 4 | gazli
# Processing Record 13 of Set 4 | grindavik
# Processing Record 14 of Set 4 | talaya
# Processing Record 15 of Set 4 | strezhevoy
# Processing Record 16 of Set 4 | ambon
# Processing Record 17 of Set 4 | port macquarie
# Processing Record 18 of Set 4 | chokurdakh
# Processing Record 19 of Set 4 | ilulissat
# Processing Record 20 of Set 4 | san patricio
# Processing Record 21 of Set 4 | nuuk
# Processing Record 22 of Set 4 | chapais
# Processing Record 23 of Set 4 | luderitz
# Processing Record 24 of Set 4 | upernavik
# Processing Record 25 of Set 4 | iqaluit
# Processing Record 26 of Set 4 | talakan
# Processing Record 27 of Set 4 | manono
# Processing Record 28 of Set 4 | klaksvik
# Processing Record 29 of Set 4 | bredasdorp
# Processing Record 30 of Set 4 | shakiso
# Processing Record 31 of Set 4 | aykhal
# Processing Record 32 of Set 4 | sterlibashevo
# Processing Record 33 of Set 4 | vao
# Processing Record 34 of Set 4 | ayan
# Processing Record 35 of Set 4 | alyangula
# Processing Record 36 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 4 | bowen
# Processing Record 38 of Set 4 | sena madureira
# Processing Record 39 of Set 4 | puerto del rosario
# Processing Record 40 of Set 4 | taltal
# Processing Record 41 of Set 4 | atasu
# Processing Record 42 of Set 4 | potsdam
# Processing Record 43 of Set 4 | beringovskiy
# Processing Record 44 of Set 4 | chuy
# Processing Record 45 of Set 4 | sitka
# Processing Record 46 of Set 4 | sal rei
# Processing Record 47 of Set 4 | yinchuan
# Processing Record 48 of Set 4 | nikolskoye
# Processing Record 49 of Set 4 | el alto
# Processing Record 50 of Set 4 | ridgecrest
# Processing Record 1 of Set 5 | saint-francois
# Processing Record 2 of Set 5 | kaitangata
# Processing Record 3 of Set 5 | merauke
# Processing Record 4 of Set 5 | olavarria
# Processing Record 5 of Set 5 | wanning
# Processing Record 6 of Set 5 | namatanai
# Processing Record 7 of Set 5 | rocha
# Processing Record 8 of Set 5 | saint anthony
# Processing Record 9 of Set 5 | guozhen
# Processing Record 10 of Set 5 | raudeberg
# Processing Record 11 of Set 5 | santa rosa
# Processing Record 12 of Set 5 | yellowknife
# Processing Record 13 of Set 5 | mount gambier
# Processing Record 14 of Set 5 | hithadhoo
# Processing Record 15 of Set 5 | cangzhou
# Processing Record 16 of Set 5 | mergui
# City not found. Skipping...
# Processing Record 17 of Set 5 | kenai
# Processing Record 18 of Set 5 | neuquen
# Processing Record 19 of Set 5 | codrington
# Processing Record 20 of Set 5 | half moon bay
# Processing Record 21 of Set 5 | harper
# Processing Record 22 of Set 5 | lagoa
# Processing Record 23 of Set 5 | bilibino
# Processing Record 24 of Set 5 | ryotsu
# Processing Record 25 of Set 5 | kruisfontein
# Processing Record 26 of Set 5 | abha
# Processing Record 27 of Set 5 | berlevag
# Processing Record 28 of Set 5 | karratha
# Processing Record 29 of Set 5 | fairbanks
# Processing Record 30 of Set 5 | sao sepe
# Processing Record 31 of Set 5 | muros
# Processing Record 32 of Set 5 | rassvet
# Processing Record 33 of Set 5 | ancud
# Processing Record 34 of Set 5 | payson
# Processing Record 35 of Set 5 | tuggurt
# City not found. Skipping...
# Processing Record 36 of Set 5 | cabo san lucas
# Processing Record 37 of Set 5 | dasoguz
# Processing Record 38 of Set 5 | gobabis
# Processing Record 39 of Set 5 | najran
# Processing Record 40 of Set 5 | norman wells
# Processing Record 41 of Set 5 | kamina
# Processing Record 42 of Set 5 | itainopolis
# Processing Record 43 of Set 5 | mecca
# Processing Record 44 of Set 5 | agogo
# Processing Record 45 of Set 5 | ponta do sol
# Processing Record 46 of Set 5 | hov
# Processing Record 47 of Set 5 | yarada
# Processing Record 48 of Set 5 | esperance
# Processing Record 49 of Set 5 | kerman
# Processing Record 50 of Set 5 | kangaatsiaq
# Processing Record 1 of Set 6 | puksoozero
# Processing Record 2 of Set 6 | kavieng
# Processing Record 3 of Set 6 | vardo
# Processing Record 4 of Set 6 | nicoya
# Processing Record 5 of Set 6 | bagdarin
# Processing Record 6 of Set 6 | cherskiy
# Processing Record 7 of Set 6 | vorontsovka
# Processing Record 8 of Set 6 | naze
# Processing Record 9 of Set 6 | bessonovka
# Processing Record 10 of Set 6 | kosh-agach
# Processing Record 11 of Set 6 | douglas
# Processing Record 12 of Set 6 | carutapera
# Processing Record 13 of Set 6 | georgetown
# Processing Record 14 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 15 of Set 6 | erzin
# Processing Record 16 of Set 6 | alta floresta
# Processing Record 17 of Set 6 | irituia
# Processing Record 18 of Set 6 | beyneu
# Processing Record 19 of Set 6 | komsomolskiy
# Processing Record 20 of Set 6 | provideniya
# Processing Record 21 of Set 6 | shimoda
# Processing Record 22 of Set 6 | tasiilaq
# Processing Record 23 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 6 | camopi
# Processing Record 25 of Set 6 | shiraz
# Processing Record 26 of Set 6 | colares
# Processing Record 27 of Set 6 | hazorasp
# Processing Record 28 of Set 6 | torbay
# Processing Record 29 of Set 6 | victoria
# Processing Record 30 of Set 6 | kawalu
# Processing Record 31 of Set 6 | padang
# Processing Record 32 of Set 6 | portland
# Processing Record 33 of Set 6 | palmer
# Processing Record 34 of Set 6 | geraldton
# Processing Record 35 of Set 6 | dunedin
# Processing Record 36 of Set 6 | roros
# Processing Record 37 of Set 6 | coromandel
# Processing Record 38 of Set 6 | mandalgovi
# Processing Record 39 of Set 6 | aguimes
# Processing Record 40 of Set 6 | salalah
# Processing Record 41 of Set 6 | seddon
# Processing Record 42 of Set 6 | arraial do cabo
# Processing Record 43 of Set 6 | fort nelson
# Processing Record 44 of Set 6 | mogadishu
# Processing Record 45 of Set 6 | isangel
# Processing Record 46 of Set 6 | paracuru
# Processing Record 47 of Set 6 | lukaya
# Processing Record 48 of Set 6 | simao
# Processing Record 49 of Set 6 | bintulu
# Processing Record 50 of Set 6 | byron bay
# Processing Record 1 of Set 7 | muli
# Processing Record 2 of Set 7 | san pedro
# Processing Record 3 of Set 7 | roseburg
# Processing Record 4 of Set 7 | umm kaddadah
# Processing Record 5 of Set 7 | fallon
# Processing Record 6 of Set 7 | abidjan
# Processing Record 7 of Set 7 | sangar
# Processing Record 8 of Set 7 | bodden town
# Processing Record 9 of Set 7 | brainerd
# Processing Record 10 of Set 7 | belyy yar
# Processing Record 11 of Set 7 | kasongo
# Processing Record 12 of Set 7 | bartica
# Processing Record 13 of Set 7 | lufilufi
# Processing Record 14 of Set 7 | zhigansk
# Processing Record 15 of Set 7 | tacuarembo
# Processing Record 16 of Set 7 | srednekolymsk
# Processing Record 17 of Set 7 | mantua
# Processing Record 18 of Set 7 | huilong
# Processing Record 19 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 20 of Set 7 | namibe
# Processing Record 21 of Set 7 | constantine
# Processing Record 22 of Set 7 | odweyne
# Processing Record 23 of Set 7 | beroroha
# Processing Record 24 of Set 7 | poniatowa
# Processing Record 25 of Set 7 | tashir
# Processing Record 26 of Set 7 | comodoro rivadavia
# Processing Record 27 of Set 7 | fare
# Processing Record 28 of Set 7 | parry sound
# Processing Record 29 of Set 7 | rongcheng
# Processing Record 30 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 31 of Set 7 | pakxan
# Processing Record 32 of Set 7 | mahibadhoo
# Processing Record 33 of Set 7 | tabuk
# Processing Record 34 of Set 7 | anadyr
# Processing Record 35 of Set 7 | raga
# Processing Record 36 of Set 7 | narsaq
# Processing Record 37 of Set 7 | gola bazar
# Processing Record 38 of Set 7 | yerbogachen
# Processing Record 39 of Set 7 | presidente medici
# Processing Record 40 of Set 7 | poum
# Processing Record 41 of Set 7 | ulcinj
# Processing Record 42 of Set 7 | evensk
# Processing Record 43 of Set 7 | goderich
# Processing Record 44 of Set 7 | agua verde
# Processing Record 45 of Set 7 | lethem
# Processing Record 46 of Set 7 | roebourne
# Processing Record 47 of Set 7 | acapulco
# Processing Record 48 of Set 7 | port lincoln
# Processing Record 49 of Set 7 | faanui
# Processing Record 50 of Set 7 | yurino
# Processing Record 1 of Set 8 | langarud
# Processing Record 2 of Set 8 | matara
# Processing Record 3 of Set 8 | lakes entrance
# Processing Record 4 of Set 8 | pundaguitan
# Processing Record 5 of Set 8 | daru
# Processing Record 6 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 7 of Set 8 | orsha
# Processing Record 8 of Set 8 | brodnica
# Processing Record 9 of Set 8 | sao felix do xingu
# Processing Record 10 of Set 8 | dryden
# Processing Record 11 of Set 8 | mehamn
# Processing Record 12 of Set 8 | mountain home
# Processing Record 13 of Set 8 | hakui
# Processing Record 14 of Set 8 | amposta
# Processing Record 15 of Set 8 | port elizabeth
# Processing Record 16 of Set 8 | kudahuvadhoo
# Processing Record 17 of Set 8 | homer
# Processing Record 18 of Set 8 | karangampel
# Processing Record 19 of Set 8 | inirida
# Processing Record 20 of Set 8 | salekhard
# Processing Record 21 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 22 of Set 8 | bucerias
# Processing Record 23 of Set 8 | weligama
# Processing Record 24 of Set 8 | varnamo
# Processing Record 25 of Set 8 | sukumo
# Processing Record 26 of Set 8 | itarema
# Processing Record 27 of Set 8 | ketchikan
# Processing Record 28 of Set 8 | waldkraiburg
# Processing Record 29 of Set 8 | yenagoa
# Processing Record 30 of Set 8 | gresham
# Processing Record 31 of Set 8 | batticaloa
# Processing Record 32 of Set 8 | parkes
# Processing Record 33 of Set 8 | jasper
# Processing Record 34 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 8 | makat
# Processing Record 36 of Set 8 | karpogory
# Processing Record 37 of Set 8 | saldanha
# Processing Record 38 of Set 8 | cheuskiny
# City not found. Skipping...
# Processing Record 39 of Set 8 | deputatskiy
# Processing Record 40 of Set 8 | tecolutilla
# Processing Record 41 of Set 8 | lazaro cardenas
# Processing Record 42 of Set 8 | superior
# Processing Record 43 of Set 8 | guerrero negro
# Processing Record 44 of Set 8 | talawdi
# City not found. Skipping...
# Processing Record 45 of Set 8 | xining
# Processing Record 46 of Set 8 | emerald
# Processing Record 47 of Set 8 | abu zabad
# Processing Record 48 of Set 8 | mporokoso
# Processing Record 49 of Set 8 | peterhead
# Processing Record 50 of Set 8 | zemio
# Processing Record 1 of Set 9 | avenal
# Processing Record 2 of Set 9 | san jeronimo
# Processing Record 3 of Set 9 | goure
# Processing Record 4 of Set 9 | hualmay
# Processing Record 5 of Set 9 | rio gallegos
# Processing Record 6 of Set 9 | college
# Processing Record 7 of Set 9 | egvekinot
# Processing Record 8 of Set 9 | gotemba
# Processing Record 9 of Set 9 | roma
# Processing Record 10 of Set 9 | mount isa
# Processing Record 11 of Set 9 | qasigiannguit
# Processing Record 12 of Set 9 | lavrentiya
# Processing Record 13 of Set 9 | aksu
# Processing Record 14 of Set 9 | maneadero
# Processing Record 15 of Set 9 | mananjary
# Processing Record 16 of Set 9 | yaan
# Processing Record 17 of Set 9 | bloomfield
# Processing Record 18 of Set 9 | grand-lahou
# Processing Record 19 of Set 9 | hami
# Processing Record 20 of Set 9 | dingle
# Processing Record 21 of Set 9 | westport
# Processing Record 22 of Set 9 | bengkulu
# Processing Record 23 of Set 9 | chernyshevskiy
# Processing Record 24 of Set 9 | necochea
# Processing Record 25 of Set 9 | agar
# Processing Record 26 of Set 9 | walvis bay
# Processing Record 27 of Set 9 | achinsk
# Processing Record 28 of Set 9 | cehegin
# Processing Record 29 of Set 9 | mocuba
# Processing Record 30 of Set 9 | bandarbeyla
# Processing Record 31 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 9 | bambanglipuro
# Processing Record 33 of Set 9 | caluquembe
# Processing Record 34 of Set 9 | willowmore
# Processing Record 35 of Set 9 | san policarpo
# Processing Record 36 of Set 9 | kizukuri
# Processing Record 37 of Set 9 | rawson
# Processing Record 38 of Set 9 | preobrazheniye
# Processing Record 39 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 40 of Set 9 | hare bay
# Processing Record 41 of Set 9 | venado tuerto
# Processing Record 42 of Set 9 | senekal
# Processing Record 43 of Set 9 | erenhot
# Processing Record 44 of Set 9 | lorengau
# Processing Record 45 of Set 9 | sorland
# Processing Record 46 of Set 9 | indiaroba
# Processing Record 47 of Set 9 | thunder bay
# Processing Record 48 of Set 9 | alice springs
# Processing Record 49 of Set 9 | fort frances
# Processing Record 50 of Set 9 | qui nhon
# Processing Record 1 of Set 10 | danane
# Processing Record 2 of Set 10 | christchurch
# Processing Record 3 of Set 10 | aklavik
# Processing Record 4 of Set 10 | gat
# Processing Record 5 of Set 10 | maniitsoq
# Processing Record 6 of Set 10 | hettstedt
# Processing Record 7 of Set 10 | sechura
# Processing Record 8 of Set 10 | masvingo
# Processing Record 9 of Set 10 | antalaha
# Processing Record 10 of Set 10 | havelock
# Processing Record 11 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 12 of Set 10 | esna
# Processing Record 13 of Set 10 | pagudpud
# Processing Record 14 of Set 10 | cap malheureux
# Processing Record 15 of Set 10 | ilinskiy
# Processing Record 16 of Set 10 | maceio
# Processing Record 17 of Set 10 | richards bay
# Processing Record 18 of Set 10 | barabinsk
# Processing Record 19 of Set 10 | abonnema
# Processing Record 20 of Set 10 | bakuriani
# Processing Record 21 of Set 10 | hervey bay
# Processing Record 22 of Set 10 | birpur
# Processing Record 23 of Set 10 | santa isabel
# Processing Record 24 of Set 10 | lapua
# Processing Record 25 of Set 10 | farias brito
# Processing Record 26 of Set 10 | husavik
# Processing Record 27 of Set 10 | hajiganj
# Processing Record 28 of Set 10 | mullaitivu
# City not found. Skipping...
# Processing Record 29 of Set 10 | smithers
# Processing Record 30 of Set 10 | honghu
# Processing Record 31 of Set 10 | prince rupert
# Processing Record 32 of Set 10 | mackay
# Processing Record 33 of Set 10 | uyuni
# Processing Record 34 of Set 10 | astoria
# Processing Record 35 of Set 10 | port hedland
# Processing Record 36 of Set 10 | ust-omchug
# Processing Record 37 of Set 10 | ahipara
# Processing Record 38 of Set 10 | dolhesti
# Processing Record 39 of Set 10 | dong hoi
# Processing Record 40 of Set 10 | arica
# Processing Record 41 of Set 10 | parnarama
# Processing Record 42 of Set 10 | rupert
# Processing Record 43 of Set 10 | shelburne
# Processing Record 44 of Set 10 | anori
# Processing Record 45 of Set 10 | beni mazar
# Processing Record 46 of Set 10 | mato verde
# Processing Record 47 of Set 10 | matagami
# Processing Record 48 of Set 10 | nabire
# Processing Record 49 of Set 10 | san vicente
# Processing Record 50 of Set 10 | gladstone
# Processing Record 1 of Set 11 | jumla
# Processing Record 2 of Set 11 | bababe
# City not found. Skipping...
# Processing Record 3 of Set 11 | oistins
# Processing Record 4 of Set 11 | ibra
# Processing Record 5 of Set 11 | chilca
# Processing Record 6 of Set 11 | saint marys
# Processing Record 7 of Set 11 | mersing
# Processing Record 8 of Set 11 | kontagora
# Processing Record 9 of Set 11 | roald
# Processing Record 10 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 11 of Set 11 | kizema
# Processing Record 12 of Set 11 | pizarro
# Processing Record 13 of Set 11 | kadoshkino
# Processing Record 14 of Set 11 | praia da vitoria
# Processing Record 15 of Set 11 | hay river
# Processing Record 16 of Set 11 | riyadh
# Processing Record 17 of Set 11 | gigmoto
# Processing Record 18 of Set 11 | valparaiso
# Processing Record 19 of Set 11 | gualaquiza
# Processing Record 20 of Set 11 | judenburg
# Processing Record 21 of Set 11 | lamu
# Processing Record 22 of Set 11 | north bend
# Processing Record 23 of Set 11 | beloha
# Processing Record 24 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 11 | bratsk
# Processing Record 26 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 27 of Set 11 | tiznit
# Processing Record 28 of Set 11 | te anau
# Processing Record 29 of Set 11 | kokoda
# Processing Record 30 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 31 of Set 11 | bandar-e anzali
# Processing Record 32 of Set 11 | la ronge
# Processing Record 33 of Set 11 | borzna
# Processing Record 34 of Set 11 | yar-sale
# Processing Record 35 of Set 11 | mayo
# Processing Record 36 of Set 11 | nagornyy
# Processing Record 37 of Set 11 | arkadelphia
# Processing Record 38 of Set 11 | bonthe
# Processing Record 39 of Set 11 | ballitoville
# Processing Record 40 of Set 11 | hukuntsi
# Processing Record 41 of Set 11 | khokholskiy
# City not found. Skipping...
# Processing Record 42 of Set 11 | maloshuyka
# City not found. Skipping...
# Processing Record 43 of Set 11 | vredendal
# Processing Record 44 of Set 11 | kango
# Processing Record 45 of Set 11 | cayenne
# Processing Record 46 of Set 11 | sijunjung
# Processing Record 47 of Set 11 | lashio
# Processing Record 48 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 49 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 50 of Set 11 | hirna
# Processing Record 1 of Set 12 | praya
# Processing Record 2 of Set 12 | whitehorse
# Processing Record 3 of Set 12 | santa isabel do rio negro
# Processing Record 4 of Set 12 | flin flon
# Processing Record 5 of Set 12 | fortuna
# Processing Record 6 of Set 12 | tyup
# Processing Record 7 of Set 12 | ikon-khalk
# Processing Record 8 of Set 12 | mabaruma
# Processing Record 9 of Set 12 | lixourion
# Processing Record 10 of Set 12 | leshan
# Processing Record 11 of Set 12 | conde
# Processing Record 12 of Set 12 | leningradskiy
# Processing Record 13 of Set 12 | dire
# Processing Record 14 of Set 12 | boyuibe
# Processing Record 15 of Set 12 | kantabanji
# Processing Record 16 of Set 12 | serenje
# Processing Record 17 of Set 12 | zdvinsk
# Processing Record 18 of Set 12 | shirokiy
# Processing Record 19 of Set 12 | porto novo
# Processing Record 20 of Set 12 | paratinga
# Processing Record 21 of Set 12 | tucuman
# Processing Record 22 of Set 12 | mahajanga
# Processing Record 23 of Set 12 | tabou
# Processing Record 24 of Set 12 | ushtobe
# Processing Record 25 of Set 12 | porto seguro
# Processing Record 26 of Set 12 | waipawa
# Processing Record 27 of Set 12 | campoverde
# Processing Record 28 of Set 12 | asau
# Processing Record 29 of Set 12 | labrea
# Processing Record 30 of Set 12 | miles city
# Processing Record 31 of Set 12 | moussoro
# Processing Record 32 of Set 12 | oron
# Processing Record 33 of Set 12 | coahuayana
# Processing Record 34 of Set 12 | uruzgan
# Processing Record 35 of Set 12 | pitimbu
# Processing Record 36 of Set 12 | jinchang
# Processing Record 37 of Set 12 | waiuku
# Processing Record 38 of Set 12 | havre-saint-pierre
# Processing Record 39 of Set 12 | dali
# Processing Record 40 of Set 12 | sakakah
# Processing Record 41 of Set 12 | la paz
# Processing Record 42 of Set 12 | brae
# Processing Record 43 of Set 12 | menongue
# Processing Record 44 of Set 12 | la sarre
# Processing Record 45 of Set 12 | coihaique
# Processing Record 46 of Set 12 | dawlatabad
# Processing Record 47 of Set 12 | monterey
# Processing Record 48 of Set 12 | svetlyy
# Processing Record 49 of Set 12 | preston
# Processing Record 50 of Set 12 | khorramshahr
# Processing Record 1 of Set 13 | kieta
# Processing Record 2 of Set 13 | ardakan
# Processing Record 3 of Set 13 | yomitan
# City not found. Skipping...
# Processing Record 4 of Set 13 | soyo
# Processing Record 5 of Set 13 | sembe
# Processing Record 6 of Set 13 | saint-imier
# Processing Record 7 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 8 of Set 13 | haimen
# Processing Record 9 of Set 13 | nhulunbuy
# Processing Record 10 of Set 13 | charlestown
# Processing Record 11 of Set 13 | kearney
# Processing Record 12 of Set 13 | port hardy
# Processing Record 13 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 13 | banyo
# Processing Record 15 of Set 13 | burgeo
# Processing Record 16 of Set 13 | ardistan
# City not found. Skipping...
# Processing Record 17 of Set 13 | san ramon
# Processing Record 18 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 19 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 20 of Set 13 | saint-augustin
# Processing Record 21 of Set 13 | gilgit
# Processing Record 22 of Set 13 | vila
# Processing Record 23 of Set 13 | broome
# Processing Record 24 of Set 13 | kasempa
# Processing Record 25 of Set 13 | camacha
# Processing Record 26 of Set 13 | bethanien
# Processing Record 27 of Set 13 | lishu
# Processing Record 28 of Set 13 | bam
# Processing Record 29 of Set 13 | glenwood springs
# Processing Record 30 of Set 13 | toguchin
# Processing Record 31 of Set 13 | pando
# Processing Record 32 of Set 13 | santa maria
# Processing Record 33 of Set 13 | coquimbo
# Processing Record 34 of Set 13 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 13 | alofi
# Processing Record 36 of Set 13 | zaraza
# Processing Record 37 of Set 13 | kholtoson
# Processing Record 38 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 39 of Set 13 | nyurba
# Processing Record 40 of Set 13 | altinopolis
# Processing Record 41 of Set 13 | road town
# Processing Record 42 of Set 13 | romanovo
# Processing Record 43 of Set 13 | ati
# Processing Record 44 of Set 13 | vila do maio
# Processing Record 45 of Set 13 | megion
# Processing Record 46 of Set 13 | srandakan
# Processing Record 47 of Set 13 | namtsy
# Processing Record 48 of Set 13 | kindu
# Processing Record 49 of Set 13 | iset
# Processing Record 50 of Set 13 | sovetskiy
# Processing Record 1 of Set 14 | laguna
# Processing Record 2 of Set 14 | boa vista
# Processing Record 3 of Set 14 | eldikan
# City not found. Skipping...
# Processing Record 4 of Set 14 | hiriyur
# Processing Record 5 of Set 14 | hamilton
# Processing Record 6 of Set 14 | poso
# Processing Record 7 of Set 14 | margate
# Processing Record 8 of Set 14 | mazagao
# Processing Record 9 of Set 14 | lichtenburg
# Processing Record 10 of Set 14 | villeneuve-saint-georges
# Processing Record 11 of Set 14 | puerto wilches
# Processing Record 12 of Set 14 | lindi
# Processing Record 13 of Set 14 | sistranda
# Processing Record 14 of Set 14 | ulundi
# Processing Record 15 of Set 14 | falmouth
# Processing Record 16 of Set 14 | wilmington
# Processing Record 17 of Set 14 | jarocin
# Processing Record 18 of Set 14 | tazovskiy
# Processing Record 19 of Set 14 | tabukiniberu
# City not found. Skipping...
# Processing Record 20 of Set 14 | tulun
# Processing Record 21 of Set 14 | ixtapa
# Processing Record 22 of Set 14 | tanjong karang
# City not found. Skipping...
# Processing Record 23 of Set 14 | yarmouth
# Processing Record 24 of Set 14 | veinticinco de mayo
# Processing Record 25 of Set 14 | bosaso
# Processing Record 26 of Set 14 | lata
# Processing Record 27 of Set 14 | tarko-sale
# Processing Record 28 of Set 14 | fengxian
# Processing Record 29 of Set 14 | kaeo
# Processing Record 30 of Set 14 | umm bab
# Processing Record 31 of Set 14 | rincon
# Processing Record 32 of Set 14 | yamaranguila
# Processing Record 33 of Set 14 | opuwo
# Processing Record 34 of Set 14 | turbat
# Processing Record 35 of Set 14 | arlit
# Processing Record 36 of Set 14 | praia
# Processing Record 37 of Set 14 | nelson bay
# Processing Record 38 of Set 14 | lasa
# Processing Record 39 of Set 14 | lubango
# Processing Record 40 of Set 14 | quatre cocos
# Processing Record 41 of Set 14 | visby
# Processing Record 42 of Set 14 | nago
# Processing Record 43 of Set 14 | sangmelima
# Processing Record 44 of Set 14 | kiunga
# Processing Record 45 of Set 14 | mahenge
# Processing Record 46 of Set 14 | rey bouba
# Processing Record 47 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 14 | pyrzyce
# Processing Record 49 of Set 14 | lagos
# Processing Record 50 of Set 14 | vanimo
# Processing Record 1 of Set 15 | manzil jamil
# City not found. Skipping...
# Processing Record 2 of Set 15 | faya
# Processing Record 3 of Set 15 | bahia blanca
# Processing Record 4 of Set 15 | kaifeng
# Processing Record 5 of Set 15 | shingu
# Processing Record 6 of Set 15 | montepuez
# Processing Record 7 of Set 15 | kletskaya
# Processing Record 8 of Set 15 | dhangadhi
# Processing Record 9 of Set 15 | sembakung
# Processing Record 10 of Set 15 | iwanai
# Processing Record 11 of Set 15 | alzamay
# Processing Record 12 of Set 15 | madaoua
# Processing Record 13 of Set 15 | mbandaka
# Processing Record 14 of Set 15 | charters towers
# Processing Record 15 of Set 15 | tilichiki
# Processing Record 16 of Set 15 | oga
# Processing Record 17 of Set 15 | sakaiminato
# Processing Record 18 of Set 15 | hanna
# Processing Record 19 of Set 15 | natchez
# Processing Record 20 of Set 15 | shintomi
# Processing Record 21 of Set 15 | reinosa
# Processing Record 22 of Set 15 | esmeraldas
# Processing Record 23 of Set 15 | middle island
# Processing Record 24 of Set 15 | prado
# Processing Record 25 of Set 15 | providencia
# Processing Record 26 of Set 15 | garlasco
# Processing Record 27 of Set 15 | adrar
# Processing Record 28 of Set 15 | andarab
# City not found. Skipping...
# Processing Record 29 of Set 15 | vostok
# Processing Record 30 of Set 15 | broken hill
# Processing Record 31 of Set 15 | zakharo
# City not found. Skipping...
# Processing Record 32 of Set 15 | kichera
# Processing Record 33 of Set 15 | kloulklubed
# Processing Record 34 of Set 15 | acari
# Processing Record 35 of Set 15 | thaba-tseka
# Processing Record 36 of Set 15 | porto santo
# Processing Record 37 of Set 15 | moyale
# Processing Record 38 of Set 15 | sainte-marie
# Processing Record 39 of Set 15 | krasnoarmeysk
# Processing Record 40 of Set 15 | mamou
# Processing Record 41 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 42 of Set 15 | bantou
# Processing Record 43 of Set 15 | high level
# Processing Record 44 of Set 15 | henties bay
# Processing Record 45 of Set 15 | killarney
# Processing Record 46 of Set 15 | yunyang
# Processing Record 47 of Set 15 | pallasovka
# Processing Record 48 of Set 15 | neiafu
# Processing Record 49 of Set 15 | saryg-sep
# Processing Record 50 of Set 15 | biak
# Processing Record 1 of Set 16 | carballo
# Processing Record 2 of Set 16 | talara
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
weather_database_df=pd.DataFrame(city_data)
weather_database_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Mende      FR  44.6667    3.5000     34.52        97         100
# 1    Inhambane      MZ -23.8650   35.3833     76.73        81          75
# 2        Tiksi      RU  71.6872  128.8694    -16.83        98         100
# 3  Port Alfred      ZA -33.5906   26.8910     73.96        78          98
# 4      Mataura      NZ -46.1927  168.8643     60.48        34          11
# 5        Bluff      NZ -46.6000  168.3333     60.80        64           0
# 6        Floro      NO  61.5996    5.0328     39.16        75          75
# 7    Jamestown      US  42.0970  -79.2353     31.59        54           0
# 8   Butaritari      KI   3.0707  172.7902     82.60        74          86
# 9      Rikitea      PF -23.1203 -134.9692     79.00        71          24
#
#    Wind Speed Current Description
# 0       14.63          light snow
# 1       14.16       broken clouds
# 2        6.17     overcast clouds
# 3        4.90     overcast clouds
# 4        1.43          few clouds
# 5       12.01           clear sky
# 6       27.63       broken clouds
# 7        7.00           clear sky
# 8       15.48     overcast clouds
# 9       19.19          few clouds

# %%
# Create the output file (CSV).
output_data_file = "C:/Users/karun/Desktop/GitRepository/World_Weather_Analysis/Weather_Database/database.csv"
# Export the City_Data into a CSV.
weather_database_df.to_csv(output_data_file, index_label="City_ID")
